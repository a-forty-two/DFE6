# %%
# HTTP, HTTPS, FTP, ICMP, -> transfer protocol
# APACHE to read hadoop environments-> WASBS
# syntax for source: container@storageaccountname.blob.core.windows.net


dbutils.fs.mount(
    source = 'wasbs://data@umbrellapotato.blob.core.windows.net',
    mount_point='/mnt/lake',
    extra_configs = {
        'fs.azure.account.key.umbrellapotato.blob.core.windows.net' : '9G0khLkHPRBBeNDB0lJDT9ynQuKgh/IRBiSNlo82ur00MSlZ1pJUVcdGihyj3IaoYRtMhm4DO5hk+AStgySDLg=='
})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: True</div>

# %%
data = spark.read.json('/mnt/lake/result/superstore.json')
# spark.read.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
